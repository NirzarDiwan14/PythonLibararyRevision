# %%
import numpy as np

# %%
arr = np.array([1,2,np.nan,4])
print(arr)

print(np.isnan(arr))
# Out:
# [ 1.  2. nan  4.]
# [False False  True False]

# %%
print(np.nan == np.nan)
# Out:
# False

# %%
print(np.nan_to_num(arr,nan = 6))
# Out:
# [1. 2. 6. 4.]

# %%
arr = np.array([1,2,3,np.inf,5,-np.inf,7])
print(np.isinf(arr))
# Out:
# [False False False  True False  True False]
