# %%
import numpy as np

# %%
arr = np.arange(6)
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
#reshape = it will convert your array in specified shape (IF NUMBER OF ELEMENTS MATCH )
new_arr = arr.reshape(2,3)

new_arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
#FLATTENING ARRAYS 
    # 1. ravel() -> view
    # 2. flatten() -> copy 

arr = np.array([[1,2,3],[4,5,6]])
print(arr)
print(arr.ravel())
print(arr.flatten())
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]
# [1 2 3 4 5 6]
